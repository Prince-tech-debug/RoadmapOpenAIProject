# %%
# !pip install openai dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (2.36.0)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: colorama in C:\Users\princ\AppData\Roaming\Python\Python314\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, dotenv
#
#    ---------------------------------------- 2/2 [dotenv]
#
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.2
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
#imports
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
#just comment the one which you dont want to use
load_dotenv(override=True)
OPENAI_API=os.getenv("OPENAI_API_KEY")
Gemini_API=os.getenv("GEMINI_API_KEY")
if Gemini_API and OPENAI_API:
    print("Both api keys are loaded")
    print(f"GEMINI={Gemini_API[:4]}...")
    print(f"OpenAI={OPENAI_API[:4]}...")
# Out:
# Both api keys are loaded
# GEMINI=AIza...
# OpenAI=sk-p...

# %%
client=OpenAI(
    api_key=Gemini_API, 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
#For OpenAI API key
Client=OpenAI(api_key=OPENAI_API)

system_prompt="You are an helpfull assistant who helps the users with queries and questions, answer every question honestly in a short paragraph, if you dont know the answer say so."
question="Can you tell what does the Fealing of being unhappy is like."
messages=[{"role":"system","content":system_prompt},{"role":"user","content":question}]

# %% [markdown]
# ### Now this is time to select which model you want to use, just dont run the cells of the model whose API key is not in your environment

# %%
#here is the gemini implementation with openAI Lib by using a base url
response=client.chat.completions.create(
    model="gemini-2.5-flash",
    temperature=0.2,    #Try chaning the temp and see how the response changes
    messages=messages
)

# %%
#classic Open ai implementation
Response=client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0.2,    #Try chaning the temp and see how the response changes
    messages=messages
)
# If you see a error here its probable because the model gpt-4o-mini is not available for your api key just check for the models which are available and 
# and try again

# %%
Gemini_2_5_response=response.choices[0].message.content

# %%
Gemini_2_5=response.choices[0].message.content

# %%
Openai_response=Response.choices[0].message.content

# %%
#This is what I got by useing gemini-2.5-flash
print(f"This is what I got by useing gemini-2.5-flash with 0.2 Temperature: \n{Gemini_2_5_response}")
print(f"This is what I got by useing gemini-2.5-flash with 0.8 Temperature: \n{Gemini_2_5}")
# Out:
# This is what I got by useing gemini-2.5-flash with 0.2 Temperature:
# The feeling of being unhappy often manifests as a heavy, sinking sensation, sometimes accompanied by a lack of energy or motivation. It can involve persistent negative thoughts, a sense of emptiness, or a general dissatisfaction with circumstances, making everyday activities feel burdensome and joy seem distant.
# This is what I got by useing gemini-2.5-flash with 0.8 Temperature:
# The feeling of being unhappy is a complex emotional state often characterized by a pervasive sense of sadness, low mood, and a lack of joy or contentment. It can manifest as a heavy feeling in your chest, a general lack of energy or motivation, and a tendency to focus on negative thoughts or experiences. You might find yourself feeling withdrawn, irritable, or simply uninterested in things that usually bring you pleasure.

# %%
# This is what I got by useing gemini-2.5-flash with 0.2 Temperature: 
# The feeling of being unhappy often manifests as a heavy, sinking sensation, sometimes accompanied by a lack of energy or motivation. It can involve 
# persistent negative thoughts, a sense of emptiness, or a general dissatisfaction with circumstances, making everyday activities feel burdensome and 
# joy seem distant.
# This is what I got by useing gemini-2.5-flash with 0.8 Temperature: 
# The feeling of being unhappy is a complex emotional state often characterized by a pervasive sense of sadness, low mood, and a lack of joy or contentment.
# It can manifest as a heavy feeling in your chest, a general lack of energy or motivation, and a tendency to focus on negative thoughts or experiences. 
# You might find yourself feeling withdrawn, irritable, or simply uninterested in things that usually bring you pleasure.
